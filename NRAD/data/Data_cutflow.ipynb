# %%
import pandas as pd

# %%
periodA = pd.read_csv("data_periodA.csv")
periodB = pd.read_csv("data_periodB.csv")
periodC = pd.read_csv("data_periodC.csv")
periodD = pd.read_csv("data_periodD.csv")
periodE = pd.read_csv("data_periodE.csv")
periodF = pd.read_csv("data_periodF.csv")
periodG = pd.read_csv("data_periodG.csv")
periodI = pd.read_csv("data_periodI.csv")
periodK = pd.read_csv("data_periodK.csv")
periodL = pd.read_csv("data_periodL.csv")

# %%
print("Period A event count:", len(periodA))
print("Period B event count:", len(periodB))
print("Period C event count:", len(periodC))
print("Period D event count:", len(periodD))
print("Period E event count:", len(periodE))
print("Period F event count:", len(periodF))
print("Period G event count:", len(periodG))
print("Period I event count:", len(periodI))
print("Period K event count:", len(periodK))
print("Period L event count:", len(periodL))
# Out:
# Period A event count: 8502362
# Period B event count: 21961396
# Period C event count: 35993996
# Period D event count: 46414887
# Period E event count: 14018146
# Period F event count: 23270480
# Period G event count: 26824924
# Period I event count: 39772740
# Period K event count: 15864384
# Period L event count: 42193641

# %%
sr_mask_A = (periodA['ht'] > 600) & (periodA['met'] > 600)
sr_mask_B = (periodB['ht'] > 600) & (periodB['met'] > 600)
sr_mask_C = (periodC['ht'] > 600) & (periodC['met'] > 600)
sr_mask_D = (periodD['ht'] > 600) & (periodD['met'] > 600)
sr_mask_E = (periodE['ht'] > 600) & (periodE['met'] > 600)
sr_mask_F = (periodF['ht'] > 600) & (periodF['met'] > 600)
sr_mask_G = (periodG['ht'] > 600) & (periodG['met'] > 600)
sr_mask_I = (periodI['ht'] > 600) & (periodI['met'] > 600)
sr_mask_K = (periodK['ht'] > 600) & (periodK['met'] > 600)
sr_mask_L = (periodL['ht'] > 600) & (periodL['met'] > 600)

# %%
print("SR Event count for Period A:", sr_mask_A.sum())
print("SR Event count for Period B:", sr_mask_B.sum())
print("SR Event count for Period C:", sr_mask_C.sum())
print("SR Event count for Period D:", sr_mask_D.sum())
print("SR Event count for Period E:", sr_mask_E.sum())
print("SR Event count for Period F:", sr_mask_F.sum())
print("SR Event count for Period G:", sr_mask_G.sum())
print("SR Event count for Period I:", sr_mask_I.sum())
print("SR Event count for Period K:", sr_mask_K.sum())
print("SR Event count for Period L:", sr_mask_L.sum())
# Out:
# SR Event count for Period A: 520
# SR Event count for Period B: 5418
# SR Event count for Period C: 12984
# SR Event count for Period D: 37107
# SR Event count for Period E: 6479
# SR Event count for Period F: 48729
# SR Event count for Period G: 41184
# SR Event count for Period I: 65904
# SR Event count for Period K: 63834
# SR Event count for Period L: 165505

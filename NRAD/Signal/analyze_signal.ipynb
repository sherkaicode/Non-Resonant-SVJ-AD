# %%
import uproot
import pandas as pd

# %%
ROOTFILES="/home/aegis/ether/replicate_deepak"
LUMI = 139  # Total Integrated Luminosity in fb^-1
version="markXI"

# %%
target_modes = ['1000_6', '1000_8', '2000_4', '2000_6', '3000_2', '3000_4']

def load_signal_data(mode):
    path_final = f"{ROOTFILES}/NRAD/Signal/{mode}_events_{version}.txt"
    data = pd.read_csv(path_final, delim_whitespace=True)
    return data
